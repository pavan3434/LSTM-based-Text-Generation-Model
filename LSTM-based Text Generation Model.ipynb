# %%
import sys
import numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import ModelCheckpoint
#from keras.utils import np_utils
from keras.utils import to_categorical

# load ascii text and covert to lowercase
filename = "wonderland.txt"
raw_text = open(filename).read()
raw_text = raw_text.lower()

# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars)) 

# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print("Total Characters: ", n_chars)
print("Total Vocab: ", n_vocab)

# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)

# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
X = numpy.reshape(dataX, (n_patterns, seq_length, 1)) 

# normalize
X = X / float(n_vocab)

# one hot encode the output variable
y = to_categorical(dataY)

# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.keras"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# fit the model
model.fit(X, y, epochs=5, batch_size=128, callbacks=callbacks_list)

# pick a random seed
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print("Seed:")
#print("\"", ''.join([int_to_char[value] for value in pattern]), "\"")

# generate characters
for i in range(100):
    x = numpy.reshape(pattern, (1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x, verbose=0)
    index = numpy.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[value] for value in pattern]
    sys.stdout.write(result)
    pattern.append(index)
    pattern = pattern[1:len(pattern)]

print("\nDone.")
# Out:
# Total Characters:  144345
# Total Vocab:  46
# Total Patterns:  144245
# Epoch 1/5
# 1127/1127 [==============================] - ETA: 0s - loss: 2.9666
# Epoch 1: loss improved from inf to 2.96656, saving model to weights-improvement-01-2.9666.keras
# 1127/1127 [==============================] - 601s 529ms/step - loss: 2.9666
# Epoch 2/5
# 1127/1127 [==============================] - ETA: 0s - loss: 2.7643
# Epoch 2: loss improved from 2.96656 to 2.76427, saving model to weights-improvement-02-2.7643.keras
# 1127/1127 [==============================] - 576s 511ms/step - loss: 2.7643
# Epoch 3/5
# 1127/1127 [==============================] - ETA: 0s - loss: 2.6581
# Epoch 3: loss improved from 2.76427 to 2.65808, saving model to weights-improvement-03-2.6581.keras
# 1127/1127 [==============================] - 567s 503ms/step - loss: 2.6581
# Epoch 4/5
# 1127/1127 [==============================] - ETA: 0s - loss: 2.5778
# Epoch 4: loss improved from 2.65808 to 2.57780, saving model to weights-improvement-04-2.5778.keras
# 1127/1127 [==============================] - 511s 453ms/step - loss: 2.5778
# Epoch 5/5
# 1127/1127 [==============================] - ETA: 0s - loss: 2.5122
# Epoch 5: loss improved from 2.57780 to 2.51220, saving model to weights-improvement-05-2.5122.keras
# 1127/1127 [==============================] - 316s 280ms/step - loss: 2.5122
# Seed:
#  toee to the soee
#
# '
# Done.

# %% [markdown]
# 14.2

# %%
import sys
import numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import ModelCheckpoint
#from keras.utils import np_utils
from keras.utils import to_categorical

# load ascii text and covert to lowercase
filename = "wonderland.txt"
raw_text = open(filename).read()
raw_text = raw_text.lower()

# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars)) 

# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print("Total Characters: ", n_chars)
print("Total Vocab: ", n_vocab)

# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)

# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
X = numpy.reshape(dataX, (n_patterns, seq_length, 1)) 

# normalize
X = X / float(n_vocab)

# one hot encode the output variable
y = to_categorical(dataY)

# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.keras"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# fit the model
# Fit the model with increased epochs
model.fit(X, y, epochs=10, batch_size=128, callbacks=callbacks_list)



# pick a random seed
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print("Seed:")
#print("\"", ''.join([int_to_char[value] for value in pattern]), "\"")

# generate characters
for i in range(100):
    x = numpy.reshape(pattern, (1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x, verbose=0)
    index = numpy.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[value] for value in pattern]
    sys.stdout.write(result)
    pattern.append(index)
    pattern = pattern[1:len(pattern)]

print("\nDone.")
# Out:
# WARNING:tensorflow:From C:\Users\Pavan\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Total Characters:  144345
# Total Vocab:  46
# Total Patterns:  144245
# WARNING:tensorflow:From C:\Users\Pavan\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Pavan\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Pavan\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1127/1127 [==============================] - ETA: 0s - loss: 2.9684
# Epoch 1: loss improved from inf to 2.96843, saving model to weights-improvement-01-2.9684.keras
# 1127/1127 [==============================] - 606s 533ms/step - loss: 2.9684
# Epoch 2/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.7656
# Epoch 2: loss improved from 2.96843 to 2.76555, saving model to weights-improvement-02-2.7656.keras
# 1127/1127 [==============================] - 599s 531ms/step - loss: 2.7656
# Epoch 3/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.6540
# Epoch 3: loss improved from 2.76555 to 2.65396, saving model to weights-improvement-03-2.6540.keras
# 1127/1127 [==============================] - 580s 515ms/step - loss: 2.6540
# Epoch 4/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.5722
# Epoch 4: loss improved from 2.65396 to 2.57215, saving model to weights-improvement-04-2.5722.keras
# 1127/1127 [==============================] - 580s 515ms/step - loss: 2.5722
# Epoch 5/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.5087
# Epoch 5: loss improved from 2.57215 to 2.50871, saving model to weights-improvement-05-2.5087.keras
# 1127/1127 [==============================] - 585s 520ms/step - loss: 2.5087
# Epoch 6/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.4484
# Epoch 6: loss improved from 2.50871 to 2.44843, saving model to weights-improvement-06-2.4484.keras
# 1127/1127 [==============================] - 571s 506ms/step - loss: 2.4484
# Epoch 7/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.3945
# Epoch 7: loss improved from 2.44843 to 2.39448, saving model to weights-improvement-07-2.3945.keras
# 1127/1127 [==============================] - 315s 279ms/step - loss: 2.3945
# Epoch 8/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.3464
# Epoch 8: loss improved from 2.39448 to 2.34643, saving model to weights-improvement-08-2.3464.keras
# 1127/1127 [==============================] - 316s 281ms/step - loss: 2.3464
# Epoch 9/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.2991
# Epoch 9: loss improved from 2.34643 to 2.29905, saving model to weights-improvement-09-2.2991.keras
# 1127/1127 [==============================] - 542s 481ms/step - loss: 2.2991
# Epoch 10/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.2568
# Epoch 10: loss improved from 2.29905 to 2.25677, saving model to weights-improvement-10-2.2568.keras
# 1127/1127 [==============================] - 591s 524ms/step - loss: 2.2568
# Seed:
#  ain
# 'i mene the cormouse toine ' said the caterpillar.
#
# 'i den toe dare hidt the mort of the soi
# Done.

# %% [markdown]
# 14.3

# %%
import sys
import numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import ModelCheckpoint
#from keras.utils import np_utils
from keras.utils import to_categorical

# load ascii text and covert to lowercase
filename = "wonderland.txt"
raw_text = open(filename).read()
raw_text = raw_text.lower()

# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars)) 

# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print("Total Characters: ", n_chars)
print("Total Vocab: ", n_vocab)

# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)

# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
X = numpy.reshape(dataX, (n_patterns, seq_length, 1)) 

# normalize
X = X / float(n_vocab)

# one hot encode the output variable
y = to_categorical(dataY)

# Define the LSTM model with additional layers and dropout
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

# Fit the model with increased epochs
model.fit(X, y, epochs=10, batch_size=128, callbacks=callbacks_list)

# Pick a random seed and generate characters

# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.keras"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]


# pick a random seed
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print("Seed:")
#print("\"", ''.join([int_to_char[value] for value in pattern]), "\"")

# generate characters
for i in range(100):
    x = numpy.reshape(pattern, (1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x, verbose=0)
    index = numpy.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[value] for value in pattern]
    sys.stdout.write(result)
    pattern.append(index)
    pattern = pattern[1:len(pattern)]

print("\nDone.")
# Out:
# Total Characters:  144345
# Total Vocab:  46
# Total Patterns:  144245
# Epoch 1/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.8603
# Epoch 1: loss did not improve from 2.25677
# 1127/1127 [==============================] - 1642s 1s/step - loss: 2.8603
# Epoch 2/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.5232
# Epoch 2: loss did not improve from 2.25677
# 1127/1127 [==============================] - 1653s 1s/step - loss: 2.5232
# Epoch 3/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.3078
# Epoch 3: loss did not improve from 2.25677
# 1127/1127 [==============================] - 1621s 1s/step - loss: 2.3078
# Epoch 4/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.1594
# Epoch 4: loss improved from 2.25677 to 2.15939, saving model to weights-improvement-04-2.1594.keras
# 1127/1127 [==============================] - 1068s 947ms/step - loss: 2.1594
# Epoch 5/10
# 1127/1127 [==============================] - ETA: 0s - loss: 2.0536
# Epoch 5: loss improved from 2.15939 to 2.05358, saving model to weights-improvement-05-2.0536.keras
# 1127/1127 [==============================] - 1396s 1s/step - loss: 2.0536
# Epoch 6/10
# 1127/1127 [==============================] - ETA: 0s - loss: 1.9729
# Epoch 6: loss improved from 2.05358 to 1.97292, saving model to weights-improvement-06-1.9729.keras
# 1127/1127 [==============================] - 1399s 1s/step - loss: 1.9729
# Epoch 7/10
# 1127/1127 [==============================] - ETA: 0s - loss: 1.9093
# Epoch 7: loss improved from 1.97292 to 1.90934, saving model to weights-improvement-07-1.9093.keras
# 1127/1127 [==============================] - 1400s 1s/step - loss: 1.9093
# Epoch 8/10
# 1127/1127 [==============================] - ETA: 0s - loss: 1.8554
# Epoch 8: loss improved from 1.90934 to 1.85539, saving model to weights-improvement-08-1.8554.keras
# 1127/1127 [==============================] - 1397s 1s/step - loss: 1.8554
# Epoch 9/10
# 1127/1127 [==============================] - ETA: 0s - loss: 1.8081
# Epoch 9: loss improved from 1.85539 to 1.80811, saving model to weights-improvement-09-1.8081.keras
# 1127/1127 [==============================] - 1406s 1s/step - loss: 1.8081
# Epoch 10/10
# 1127/1127 [==============================] - ETA: 0s - loss: 1.7650
# Epoch 10: loss improved from 1.80811 to 1.76497, saving model to weights-improvement-10-1.7650.keras
# 1127/1127 [==============================] - 1404s 1s/step - loss: 1.7650
# Seed:
# d the ming and the was ani a little to the white rabbit, and she was not a little began to the was a
# Done.
